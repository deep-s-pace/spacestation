# %% [markdown]
# # 장렬한 실패의 흔적

# %%
# !pip install geopy
# !pip install osmnx

# from geopy.geocoders import Nominatim
# import osmnx as ox 

# import networkx as nx
# import osmnx as ox
# import requests
# import matplotlib.cm as cm
# import matplotlib.colors as colors

# ox.config(use_cache=True, log_console=True)
# ox.__version__

# conda create -n ox --strict-channel-priority osmnx

# !pip install path/to/file/GDAL_file.whl
# !pip install path/to/file/Fiona_file.whl

# import osmnx as ox, networkx as nx, geopandas as gpd, matplotlib.pyplot as plt
# from shapely.geometry import Point, Polygon, LineString
# from descartes import PolygonPatch
# import requests
# import matplotlib.cm as cm
# import matplotlib.colors as colors
# ox.config(use_cache=True, log_console=True)
# ox.__version__
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7d1183d1b247> in <module>
#       1 get_ipython().system('pip install geopy')
#       2 from geopy.geocoders import Nominatim
# ----> 3 import osmnx as ox
#
# ModuleNotFoundError: No module named 'osmnx'

# %% [markdown]
# # 재도전

# %%
# !pip install wheel
# !pip install pipwin
# Out:
# ...
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8782 sha256=c8ddfe3240032d8e36558e17e7eaea494bbcdb203bd184c1351cec743e387999
#   Stored in directory: c:\users\sdg\appdata\local\pip\cache\wheels\f4\a8\76\372879a40d2d4dd7de23efd867ed37112687429b8d0dda4545
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13709 sha256=c8277eef6edea6697f91f1ca22c3800e588d7999c870c73e9fdcb8eb2e2cc55f
#   Stored in directory: c:\users\sdg\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# ...
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26004 sha256=0360d3cb215a9fe47c3a52330cab89383f007ac511f205ceb5b7c0577d1c2100
#   Stored in directory: c:\users\sdg\appdata\local\pip\cache\wheels\d5\88\34\ccb5bb40eb3178a134eb293e6c363928c5bcfba0b91031db76
# Successfully built pipwin docopt pyjsparser
# ...

# %% [markdown]
# # 설치 성공

# %%
# !pipwin install numpy
# !pipwin install pandas
# !pipwin install shapely
# !pipwin install gdal
# !pipwin install fiona
# !pipwin install pyproj
# !pipwin install six
# !pipwin install rtree
# !pipwin install geopandas
# Out:
# Building cache. Hang on . . .
# Done
# Package `numpy` found in cache
# ...
# https://download.lfd.uci.edu/pythonlibs/x6hvwk7i/numpy-1.22.3+mkl-cp38-cp38-win32.whl
# numpy-1.22.3+mkl-cp38-cp38-win32.whl
# ...

# %%
import geopandas as gpd

# %%
import json
import requests
url = 'http://ip-api.com/json'
data = requests.get(url)
res = data.json()
print(res)
# Out:
# {'status': 'success', 'country': 'South Korea', 'countryCode': 'KR', 'region': '41', 'regionName': 'Gyeonggi-do', 'city': 'Icheon-si', 'zip': '173', 'lat': 37.277, 'lon': 127.441, 'timezone': 'Asia/Seoul', 'isp': 'Korea Telecom', 'org': 'Kornet', 'as': 'AS4766 Korea Telecom', 'query': '175.197.170.228'}

# %%
# !pip install folium

# %%
! pip install PyMySQL

# %%
import folium 
import pymysql 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
sns.set()

# %%
plt.rc('font', family='NanumGothic') 
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
# db connect and select 
conn = pymysql.connect(host='localhost', user = 'root', db = 'store_svc_m',charset = 'utf8') 

# Connection으로부터 Curcor생성
curs = conn.cursor(pymysql.cursors.DictCursor)

# DB내 테이블 생성하기
#curs.execute("create table add_info_m ( mgmt_num varchar(25) not null comment '관리번호' primary key, adm_dong_cd varchar(10) null comment '행정동코드', adm_dong_nm varchar(50) null comment '행정동명', zipcode varchar(5) null comment '우편번호', zipcode_seq varchar(3) null comment '우편번호일련번호', plent_dlvr_nm varchar(100) null comment '다량배달처명', build_rgst_nm varchar(100) null comment '건축물대장건물명', sgg_build_nm varchar(100) null comment '시군구건물명', multi_unit_yn varchar(1) null comment '공동주택여부' );")
curs.execute("create table store_info_k ( store_seq int(15) not null comment '상가업소번호' primary key, store_nm varchar(500) null comment '상호명', store_sub_nm varchar(500) null comment '지점명', bsn_sector_big_cd varchar(500) null comment '상권업종대분류코드', bsn_sector_big_nm varchar(500) null comment '상권업종대분류명', bsn_sector_mid_cd varchar(500) null comment '상권업종중분류코드', bsn_sector_mid_nm varchar(500) null comment '상권업종중분류명', bsn_sector_small_cd varchar(500) null comment '상권업종소분류코드', bsn_sector_small_nm varchar(500) null comment '상권업종소분류명', stdrd_Ind_type_cd varchar(500) null comment '표준산업분류코드', stdrd_Ind_type_nm varchar(500) null comment '표준산업분류명', sd_cd varchar(500) null comment '시도코드', sd_nm varchar(500) null comment '시도명', sgg_cd varchar(500) null comment '시군구코드', sgg_nm varchar(500) null comment '시군구명', adm_dong_cd varchar(500) null comment '행정동코드', adm_dong_nm varchar(500) null comment '행정동명', law_dong_cd varchar(500) null comment '법정동코드', law_dong_nm varchar(500) null comment '법정동명', jb_cd varchar(500) null comment '지번코드', land_dv_cd varchar(500) null comment '대지구분코드', land_dv_nm varchar(500) null comment '대지구분명', jb_main_num varchar(500) null comment '지번본번지', jb_sub_num varchar(500) null comment '지번부번지', jb_adrs varchar(500) null comment '지번주소', road_cd varchar(500) null comment '도로명코드', road_nm varchar(500) null comment '도로명', build_main_num varchar(500) null comment '건물본번지', build_sub_num varchar(500) null comment '건물부번지', build_mgmt_num varchar(500) null comment '건물관리번호', build_nm varchar(500) null comment '건물명', road_adrs varchar(500) null comment '도로명주소', past_post_num varchar(500) null comment '구우편번호', post_num varchar(500) null comment '신우편번호', dong_info varchar(500) null comment '동정보', grade_info varchar(500) null comment '층정보', ho_info varchar(500) null comment '호정보', inf_longtitude varchar(500) null comment '경도', inf_latitude varchar(500) null comment '위도' );")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-31-803bd6a627f1> in <module>
#       7 # DB내 테이블 생성하기
#       8 #curs.execute("create table add_info_m ( mgmt_num varchar(25) not null comment '관리번호' primary key, adm_dong_cd varchar(10) null comment '행정동코드', adm_dong_nm varchar(50) null comment '행정동명', zipcode varchar(5) null comment '우편번호', zipcode_seq varchar(3) null comment '우편번호일련번호', plent_dlvr_nm varchar(100) null comment '다량배달처명', build_rgst_nm varchar(100) null comment '건축물대장건물명', sgg_build_nm varchar(100) null comment '시군구건물명', multi_unit_yn varchar(1) null comment '공동주택여부' );")
# ...

# %%
#api가져와서 DB에 넣기 부분인데, 레퍼런스는 아래
# https://stricky.tistory.com/116

# %%
sql = "select sgg_nm, count(*) as cnt from store_svc_m.store_info_k where bsn_sector_small_cd = 'S02A01' and sd_nm = '서울특별시' group by sgg_nm"
curs.execute(sql)

gu_info = ""

gu_parmc_cnt = pd.DataFrame(data=gu_info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-a3905c49459a> in <module>
#       4 gu_info = ""
#       5
# ----> 6 gu_parmc_cnt = pd.DataFrame(data=gu_info)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
gu_parmc_cnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-03fc849bdf20> in <module>
# ----> 1 gu_parmc_cnt
#
# NameError: name 'gu_parmc_cnt' is not defined

# %%
#데이터 input 하기
#미완
LOAD DATA LOCAL infile "/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_서울_202112.csv" INTO TABLE test;
# Out:
#   File "<ipython-input-34-d3f7d4717b18>", line 3
#     LOAD DATA LOCAL infile "/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_서울_202112.csv" INTO TABLE test;
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# https://stricky.tistory.com/182
# https://stricky.tistory.com/170
# https://stricky.tistory.com/182

# %% [markdown]
# # 파이썬으로 위도경도 추출하기

# %%
import pandas as pd

# %%
csv = pd.read_csv('./incheon_coffeeshop_20210805.csv',encoding='cp949')
print(csv.head())
# Out:
#    연번          사업장명                소재지지번주소                  소재지도로명주소  \
# 0   1  Cafe Arancia  인천광역시 중구 내동 212-22 1층  인천광역시 중구 우현로49번길 10-5 1층
# 1   2   디저트카페 아네모오네    인천광역시 중구 송학동3가 7-26     인천광역시 중구 신포로35번길 10-1
# 2   3         관동오리진     인천광역시 중구 관동1가 14-3       인천광역시 중구 신포로27번길 96
# 3   4          카페맑음      인천광역시 중구 신포동 48-3        인천광역시 중구 신포로 32-21
# 4   5            팟알       인천광역시 중구 관동1가 17     인천광역시 중구 신포로27번길 96-2
#
#       데이터기준일자
# 0  2021-08-05
# 1  2021-08-05
# 2  2021-08-05
# 3  2021-08-05
# 4  2021-08-05

# %%
# 데이터프레임 주소값 추출
address= csv['소재지도로명주소']
print(address.head())
# Out:
# 0    인천광역시 중구 우현로49번길 10-5 1층
# 1       인천광역시 중구 신포로35번길 10-1
# 2         인천광역시 중구 신포로27번길 96
# 3          인천광역시 중구 신포로 32-21
# 4       인천광역시 중구 신포로27번길 96-2
# Name: 소재지도로명주소, dtype: object

# %%
# 주소 데이터 깔끔하게 다듬기
for i in range(len(address)):
    a = address[i].split(' ')
    address[i] = " ".join(a[0:4])
print(address)
# Out:
# <ipython-input-38-b078f1dfd4c0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   address[i] = " ".join(a[0:4])
# 0     인천광역시 중구 우현로49번길 10-5
# 1     인천광역시 중구 신포로35번길 10-1
# 2       인천광역시 중구 신포로27번길 96
# 3        인천광역시 중구 신포로 32-21
# 4     인천광역시 중구 신포로27번길 96-2
#               ...
# 75      인천광역시 중구 우현로39번길 12
# 76      인천광역시 중구 우현로45번길 25
# 77    인천광역시 중구 신포로31번길 51-1
# 78      인천광역시 중구 개항로53번길 21
# 79          인천광역시 중구 우현로 12
# Name: 소재지도로명주소, Length: 80, dtype: object

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')
# 위도, 경도 반환하는 함수
def geocoding(address):
    geo = geo_local.geocode(address)
    x_y = [geo.latitude, geo.longitude]
    return x_y

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'카페이름': csv['사업장명'],'상세주소':csv['소재지도로명주소'],'주소':address,'위도':latitude,'경도':longitude})

#df저장
address_df.to_csv('jungu_incheon_coffeeshop.csv')

# %%
address_df
# Out:
#             카페이름                   상세주소                     주소         위도  \
# 0   Cafe Arancia  인천광역시 중구 우현로49번길 10-5  인천광역시 중구 우현로49번길 10-5  37.471642
# 1    디저트카페 아네모오네  인천광역시 중구 신포로35번길 10-1  인천광역시 중구 신포로35번길 10-1  37.473394
# 2          관동오리진    인천광역시 중구 신포로27번길 96    인천광역시 중구 신포로27번길 96  37.472794
# 3           카페맑음     인천광역시 중구 신포로 32-21     인천광역시 중구 신포로 32-21  37.470997
# 4             팟알  인천광역시 중구 신포로27번길 96-2  인천광역시 중구 신포로27번길 96-2  37.472794
# ..           ...                    ...                    ...        ...
# 75          낭만카페    인천광역시 중구 우현로39번길 12    인천광역시 중구 우현로39번길 12  37.470894
# 76         또바기커피    인천광역시 중구 우현로45번길 25    인천광역시 중구 우현로45번길 25  37.471257
# 77        카페와비사비  인천광역시 중구 신포로31번길 51-1  인천광역시 중구 신포로31번길 51-1  37.472425
# 78         카페파구스    인천광역시 중구 개항로53번길 21    인천광역시 중구 개항로53번길 21  37.472645
# 79         이삭커피숍        인천광역시 중구 우현로 12        인천광역시 중구 우현로 12  37.472768
#
#             경도
# 0   126.627360
# 1   126.623144
# 2   126.622593
# ...

# %% [markdown]
# # 특정 위치 내 주변 시설물 정보 도출하기 feat. 카카오 지도 api

# %% [raw]
# 레퍼런스 : https://haries.tistory.com/6?category=885610

# %%
import requests
import pandas as pd
import numpy as np
import folium
from folium.plugins import MiniMap

# %%
##카카오 API
## region에는 '성산일출봉 전기충전소' 검색명이 들어갈 것임
## page_num은 1~3이 입력될 건데, 한 페이지 당 검색목록이 최대 15개임.
## 만약 page_num이 4이상이 되면 3페이지랑 같은 15개의 결과 값을 가져옴. 그래서 1~3만 쓰는 것임
## 입력 예시 -->> headers = {"Authorization": "KakaoAK f221u3894o198123r9"}
## ['meta']['total_count']은 내가 '성산일출봉 전기충전소'를 검색했을 때, 나오는 총 결과 값. 
## ['meta']['total_count']이 45보다 크면 45개만 가져오게 됨


def elec_location(region,page_num):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {'query': region,'page': page_num}
    headers = {"Authorization": "KakaoAK 876a5e05cd1bb1391f63c6435017f680"} #rest api key

    places = requests.get(url, params=params, headers=headers).json()['documents']
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    if total > 45:
        print(total,'개 중 45개 데이터밖에 가져오지 못했습니다!')
    else :
        print('모든 데이터를 가져왔습니다!')
    return places

# %%
## 이 함수는 위 함수 결과 값(1 ~ 45개) 하나하나 분리해서 저장할 것임
## 1번 결과 값 안에는 1번 충전소 이름, 위도, 경도, 전화번호, 도로명 주소 등이 있는데 각각 배열에 저장
## 우리는 충전소 ID, 충전소 이름, 위도, 경도, 도로명주소, 사이트주소를 저장할 것임

def elec_info(places):
    X = []
    Y = []
    stores = []
    road_address = []
    place_url = []
    ID = []
    for place in places:
        X.append(float(place['x']))
        Y.append(float(place['y']))
        stores.append(place['place_name'])
        road_address.append(place['road_address_name'])
        place_url.append(place['place_url'])
        ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    return df

# %%
## 여러개으 키워드를 검색할 때 사용할 함수임
## location_name에는 ['성산일출봉 전기충전소, '한림공원 전기충전소', ... ,'모슬포 전기충전소']처럼 배열이 입력

def keywords(location_name):
    df = None
    for loca in location:
        for page in range(1,4):
            local_name = elec_location(loca, page)
            local_elec_info = elec_info(local_name)

            if df is None:
                df = local_elec_info
            elif local_elec_info is None:
                continue
            else:
                df = pd.concat([df, local_elec_info],join='outer', ignore_index = True)
    return df

# %%
##지도로 보여주기

def make_map(dfs):
    # 지도 생성하기
    m = folium.Map(location=[33.4935,126.6266],   # 기준좌표: 제주어딘가로 내가 대충 설정
                   zoom_start=12)

    # 미니맵 추가하기
    minimap = MiniMap() 
    m.add_child(minimap)

    # 마커 추가하기
    for i in range(len(dfs)):
        folium.Marker([df['Y'][i],df['X'][i]],
                  tooltip=dfs['stores'][i],
                  popup=dfs['place_url'][i],
                  ).add_to(m)
    return m

# %%
## 여기 두 개 키워드처럼 가까운 거리에 있는 키워드를 입력하면 
## 중복해서 전기충전소를 검색할 가능성이 아주 놓기 때문에
## drop_duplicates를 해주고 인덱스 리셋을 해준다

location = ['성산일출봉 전기충전소', '광치기해수욕장 전기충전소']
df = keywords(location)
df = df.drop_duplicates(['ID'])
df = df.reset_index()

make_map(df)
# Out:
# 모든 데이터를 가져왔습니다!
# 모든 데이터를 가져왔습니다!
# 모든 데이터를 가져왔습니다!
# 72 개 중 45개 데이터밖에 가져오지 못했습니다!
# 72 개 중 45개 데이터밖에 가져오지 못했습니다!
# 72 개 중 45개 데이터밖에 가져오지 못했습니다!
# ...

# %% [markdown]
# ## 위도, 경도, 키워드 조합으로 46개 이상 결과값 모두 가져오기

# %%
import requests
import pandas as pd
import numpy as np
import folium
from folium.plugins import MiniMap
import requests
import folium

# %%
##카카오 API
def whole_region(keyword, start_x,start_y,end_x,end_y):
    #print(start_x,start_y,end_x,end_y)
    page_num = 1
    # 데이터가 담길 리스트
    all_data_list = []
    
    while(1):
        url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
        params = {'query': keyword,'page': page_num, 
                 'rect': f'{start_x},{start_y},{end_x},{end_y}'}
        headers = {"Authorization": "KakaoAK 876a5e05cd1bb1391f63c6435017f680"}
        ## 입력예시 -->> headers = {"Authorization": "KakaoAK f64acbasdfasdfasf70e4f52f737760657"}
        resp = requests.get(url, params=params, headers=headers)

        search_count = resp.json()['meta']['total_count']
        print('총 개수',search_count)
        
        if search_count > 45:
            print('좌표 4등분')
            dividing_x = (start_x + end_x) / 2
            dividing_y = (start_y + end_y) / 2
            ## 4등분 중 왼쪽 아래
            all_data_list.extend(whole_region(keyword, start_x,start_y,dividing_x,dividing_y))
            ## 4등분 중 오른쪽 아래
            all_data_list.extend(whole_region(keyword, dividing_x,start_y,end_x,dividing_y))
            ## 4등분 중 왼쪽 위
            all_data_list.extend(whole_region(keyword, start_x,dividing_y,dividing_x,end_y))
            ## 4등분 중 오른쪽 위
            all_data_list.extend(whole_region(keyword, dividing_x,dividing_y,end_x,end_y))
            return all_data_list
        
        else:
            if resp.json()['meta']['is_end']:
                all_data_list.extend(resp.json()['documents'])
                return all_data_list
            # 아니면 다음 페이지로 넘어가서 데이터 저장
            else:
                print('다음페이지')
                page_num += 1
                all_data_list.extend(resp.json()['documents'])

# %%
def overlapped_data(keyword, start_x, start_y, next_x, next_y, num_x, num_y):
    # 최종 데이터가 담길 리스트
    overlapped_result = []

    # 지도를 사각형으로 나누면서 데이터 받아옴
    for i in range(1,num_x+1):   ## 1,10
        end_x = start_x + next_x
        initial_start_y = start_y
        for j in range(1,num_y+1):  ## 1,6
            end_y = initial_start_y + next_y
            each_result= whole_region(keyword, start_x,initial_start_y,end_x,end_y)
            overlapped_result.extend(each_result)
            initial_start_y = end_y
        start_x = end_x
    
    return overlapped_result

# %%
def make_map(dfs):
    # 지도 생성하기
    m = folium.Map(location=[33.4935,126.6266],   # 기준좌표: 제주어딘가
                   zoom_start=12)

    # 미니맵 추가
    minimap = MiniMap() 
    m.add_child(minimap)

    # 마커
    for i in range(len(dfs)):
        folium.Marker([df['Y'][i],df['X'][i]],    # 제주 어딘가
                  tooltip=dfs['stores'][i],
                  popup=dfs['place_url'][i],
                  ).add_to(m)
    return m

# %%
# 시작 x 좌표 및 증가값
keyword = '공영주차장'
start_x = 126.45
start_y = 33.47
next_x = 0.01
next_y = 0.01
num_x = 12
num_y = 6

# %%
overlapped_result = overlapped_data(keyword, start_x, start_y, next_x, next_y, num_x, num_y)

# 최종 데이터가 담긴 리스트 중복값 제거
results = list(map(dict, collections.OrderedDict.fromkeys(tuple(sorted(d.items())) for d in overlapped_result)))
X = []
Y = []
stores = []
road_address = []
place_url = []
ID = []
for place in results:
    
    X.append(float(place['x']))
    Y.append(float(place['y']))
    stores.append(place['place_name'])
    road_address.append(place['road_address_name'])
    place_url.append(place['place_url'])
    ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    
print('total_reuslt_number = ',len(df))
# Out:
# 총 개수 0
# 총 개수 0
# 총 개수 1
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 4
# 총 개수 0
# 총 개수 0
# 총 개수 5
# 총 개수 26
# 다음페이지
# 총 개수 26
# 총 개수 4
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 2
# 총 개수 5
# 총 개수 5
# 총 개수 0
# 총 개수 2
# 총 개수 0
# 총 개수 5
# 총 개수 9
# 총 개수 1
# 총 개수 2
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 1
# 총 개수 0
# 총 개수 1
# 총 개수 3
# 총 개수 0
# 총 개수 0
# 총 개수 1
# 총 개수 2
# 총 개수 9
# 총 개수 16
# 다음페이지
# 총 개수 16
# 총 개수 0
# 총 개수 1
# 총 개수 9
# 총 개수 10
# 총 개수 10
# 총 개수 20
# 다음페이지
# 총 개수 20
# 총 개수 0
# 총 개수 0
# 총 개수 10
# 총 개수 18
# 다음페이지
# 총 개수 18
# 총 개수 7
# 총 개수 13
# 총 개수 0
# 총 개수 16
# 다음페이지
# 총 개수 16
# 총 개수 1
# 총 개수 21
# 다음페이지
# 총 개수 21
# 총 개수 3
# 총 개수 10
# 총 개수 1
# 총 개수 2
# 총 개수 0
# 총 개수 1
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 0
# 총 개수 2
# 총 개수 4
# 총 개수 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-de1e03997a40> in <module>
#       2
# ...

# %%
print('total_reuslt_number = ',len(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-e8c856ea302f> in <module>
# ----> 1 print('total_reuslt_number = ',len(df))
#
# NameError: name 'df' is not defined

# %%
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a6b3bba78a8e> in <module>
# ----> 1 display(df.head())
#
# NameError: name 'df' is not defined

# %%
make_map(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 이제, 진짜 반경 내 시설물 개수를 카운팅해보자

# %%
#주소를 위도&경도로 바꾼다.
import pandas as pd
csv = pd.read_csv('./sandan_location.csv',encoding='cp949')
# print(csv.head())
# 데이터프레임 주소값 추출
address= csv['소재지도로명주소']
print(address)
# Out:
# 0     경상남도 창원시 의창구 차룡로48번길 66
# 1           경기도 시흥시 소망공원로 232
# 2         대구광역시 달서구 성서공단남로 37
# 3          인천광역시 남동구 호구포로 183
# 4             대구시 달서구 성서로 329
# 5        광주광역시 광산구 하남산단6번로 57
# 6    경기도 성남시 중원구 사기막골로62번길 33
# 7          인천광역시 남동구 호구포로 139
# 8             인천 남동구 능허대로 583
# 9              경기 단원구 연수원로 10
# Name: 소재지도로명주소, dtype: object

# %%
# 주소 데이터 깔끔하게 다듬기
for i in range(len(address)):
    a = address[i].split(' ')
    address[i] = " ".join(a[0:4])
print(address)
# Out:
# 0     경상남도 창원시 의창구 차룡로48번길
# 1        경기도 시흥시 소망공원로 232
# 2      대구광역시 달서구 성서공단남로 37
# 3       인천광역시 남동구 호구포로 183
# 4          대구시 달서구 성서로 329
# 5     광주광역시 광산구 하남산단6번로 57
# 6    경기도 성남시 중원구 사기막골로62번길
# 7       인천광역시 남동구 호구포로 139
# 8          인천 남동구 능허대로 583
# 9           경기 단원구 연수원로 10
# Name: 소재지도로명주소, dtype: object
# <ipython-input-46-b078f1dfd4c0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   address[i] = " ".join(a[0:4])

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# %%
# 위도, 경도 반환하는 함수
def geocoding(address):
    geo = geo_local.geocode(address)
    x_y = [geo.latitude, geo.longitude]
    return x_y

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'산업단지명': csv['사업장명'],'상세주소':csv['소재지도로명주소'],'주소':address,'위도':latitude,'경도':longitude})
address_df
# Out:
#         산업단지명                   상세주소                     주소         위도  \
# 0      창원드림타운   경상남도 창원시 의창구 차룡로48번길   경상남도 창원시 의창구 차룡로48번길  35.243940
# 1    시화동원베네스트      경기도 시흥시 소망공원로 232      경기도 시흥시 소망공원로 232  37.336584
# 2      성서드림타운    대구광역시 달서구 성서공단남로 37    대구광역시 달서구 성서공단남로 37  35.830309
# 3    후이즈스마트타워     인천광역시 남동구 호구포로 183     인천광역시 남동구 호구포로 183  37.390595
# 4   성서동원비즈플랫폼        대구시 달서구 성서로 329        대구시 달서구 성서로 329  35.854099
# 5     광주하남KBI   광주광역시 광산구 하남산단6번로 57   광주광역시 광산구 하남산단6번로 57  35.202342
# 6       성남센터M  경기도 성남시 중원구 사기막골로62번길  경기도 성남시 중원구 사기막골로62번길  37.434652
# 7        청류지산     인천광역시 남동구 호구포로 139     인천광역시 남동구 호구포로 139  37.390595
# 8  금호오션타워오피스텔        인천 남동구 능허대로 583        인천 남동구 능허대로 583  37.387152
# 9      안산드림타운         경기 단원구 연수원로 10         경기 단원구 연수원로 10  37.321486
#
#            경도
# 0  128.627911
# 1  126.718105
# 2  128.490869
# 3  126.701239
# 4  128.507291
# 5  126.809920
# 6  127.174024
# 7  126.701239
# 8  126.691229
# 9  126.799330

# %%
#df저장
#address_df.to_csv('sandan_loca.csv') 
point1 = address_df[['위도']]
point2 = address_df[['경도']]
name = address_df[['산업단지명']]
print(point1.loc[0])#위도
print(point2.loc[0])#경도
print(name.loc[0])#산업단지명
# Out:
# 위도    35.24394
# Name: 0, dtype: float64
# 경도    128.627911
# Name: 0, dtype: float64
# 산업단지명    창원드림타운
# Name: 0, dtype: object

# %%
#반복문을 만들것이다.
#위도&경도 순차적으로 넣기
for i in range (0, 8):
#     print(point1.loc[i])
#     print(point2.loc[i])
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'

    #원하는 검색어을 스타벅스 자리에, 경도는 x에, 위도는 y에, 반경은 10000에, 카테고리는 위의 표를 보고 해당되는 카테고리를 적어주세요
    params = {'query' : '체육시설', 'x' : point2.loc[i], 'y' : point1.loc[i], 'radius' : 700} #카테고리 참고하기

    ## 본인의 카카오 맵 API의 REST API키를 바로 아래 한글로 된 코드를 지우고 입력해주세요
    headers = {"Authorization": "KakaoAK 876a5e05cd1bb1391f63c6435017f680"}

    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']

    ##places는 검색이 잘 되었는지 체크하는 용도로 확인해주시면 됩니다. 다시 말씀드리지만 places에는 45개 데이터가 한계입니다...
    ## 페이지 수를 늘려도, 한 페이지 안에서 보여줄 수 있는 한계치를 아무리 높혀도 45개 이상 안 보여 줍니다. 저는 페이지 설정은 보시다시피 하지는 않았습니다. 
    places = requests.get(url, params=params, headers=headers).json()['documents']

    ## 원하는 개수는 total변수 안에 있습니다.
    #print(name.loc[i], " : ", total)
    print(total)
    print(places)
# Out:
# 1
# [{'address_name': '경남 창원시 의창구 팔용동 39-5', 'category_group_code': '', 'category_group_name': '', 'category_name': '스포츠,레저 > 스포츠시설', 'distance': '390', 'id': '458576218', 'phone': '', 'place_name': '창원2020배드민턴센터', 'place_url': 'http://place.map.kakao.com/458576218', 'road_address_name': '경남 창원시 의창구 사화로 272', 'x': '128.63211835342', 'y': '35.2432492024823'}]
# 4
# ...

# %%
#반복문을 만들것이다.
#일단 분류코드를 pd에 넣는다.

"""
[대분류]
https://developers.kakao.com/docs/latest/ko/local/dev-guide#search-by-keyword-request-category-group-code

[상세분류]
교통시설 : 버스정류장, 지하철역, 주차장
상업시설 : 편의점, 식당, 문구점, 세탁소
의료시설 : 병의원, 약국, 보건수 
공원시설 : 공원
행정시설 : 주민센터, 우체국
금융시설 : 은행
문화체육시설 : 공공도서관, 영화관, 커피전문점, 체육시설
"""
csv_classification = pd.read_csv('./classification.csv')
address_df2 = pd.DataFrame({'대분류': csv_classification['대분류'],'코드': csv_classification['코드'],'상세분류': csv_classification['상세분류']})
address_df2
# code = address_df2[[0],['코드']]
# code.loc[[0]]
# Out:
#           대분류   코드   상세분류
# 0        대형마트  MT1     마트
# 1         편의점  CS2    편의점
# 2   어린이집, 유치원  PS3   어린이집
# 3   어린이집, 유치원  PS4    유치원
# 4          학교  SC4     학교
# 5         주차장  PK6    주차장
# 6         주차장  PK6  공영주차장
# 7    주유소, 충전소  OL7    주유소
# 8    주유소, 충전소  OL7    충전소
# 9        지하철역  SW8   지하철역
# 10         은행  BK9     은행
# 11       문화시설  CT1    영화관
# 12       문화시설  CT2    문구점
# 13       문화시설  CT3    세탁소
# 14       문화시설  CT4   체육시설
# 15       문화시설  CT4    도서관
# 16       공공기관  PO3    보건소
# 17       공공기관  PO4   주민센터
# 18       공공기관  PO4    도서관
# 19       공공기관  PO4    우체국
# 20       관광명소  AT4     공원
# 21        음식점  FD6     식당
# 22         카페  CE7    커피숍
# 23         병원  HP8     병원
# 24         약국  PM9     약국
# 25       분류없음  NaN     공원
# 26       분류없음  NaN   체육시설

# %%
code = address_df2.iloc[0,1]
code
query = address_df2.iloc[0,2]
query
# Out:
# '마트'

# %%
#반복문을 만들것이다.
#대분류 있는 버전
for i in range (0,26):
    query = address_df2.iloc[i,2]
    code = address_df2.iloc[i,1]
    
    print("==========[",query,"] ==========")
    #위도&경도 순차적으로 넣기
    for i in range (0, 10):
    #     print(point1.loc[i])
    #     print(point2.loc[i])
        url = 'https://dapi.kakao.com/v2/local/search/keyword.json'

        #원하는 검색어을 스타벅스 자리에, 경도는 x에, 위도는 y에, 반경은 10000에, 카테고리는 위의 표를 보고 해당되는 카테고리를 적어주세요
        params = {'query' : query, 'category_group_code' : code, 'x' : point2.loc[i], 'y' : point1.loc[i], 'radius' : 700} #카테고리 참고하기

        ## 본인의 카카오 맵 API의 REST API키를 바로 아래 한글로 된 코드를 지우고 입력해주세요
        headers = {"Authorization": "KakaoAK 876a5e05cd1bb1391f63c6435017f680"}

        total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
#         p_name = requests.get(url, params=params, headers=headers).json()['meta']['category_name']
#         distance = requests.get(url, params=params, headers=headers).json()['meta']['distance']

        ##places는 검색이 잘 되었는지 체크하는 용도로 확인해주시면 됩니다. 다시 말씀드리지만 places에는 45개 데이터가 한계입니다...
        ## 페이지 수를 늘려도, 한 페이지 안에서 보여줄 수 있는 한계치를 아무리 높혀도 45개 이상 안 보여 줍니다. 저는 페이지 설정은 보시다시피 하지는 않았습니다. 
#         places = requests.get(url, params=params, headers=headers).json()['documents']

        ## 원하는 개수는 total변수 안에 있습니다.
        #print(name.loc[i], " : ", total)
        print( "검색어 : ",query, "개수 : ",total)
# Out:
# ==========[ 마트 ] ==========
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  2
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# 검색어 :  마트 개수 :  0
# ==========[ 편의점 ] ==========
# 검색어 :  편의점 개수 :  2
# 검색어 :  편의점 개수 :  5
# 검색어 :  편의점 개수 :  10
# 검색어 :  편의점 개수 :  2
# 검색어 :  편의점 개수 :  25
# 검색어 :  편의점 개수 :  6
# 검색어 :  편의점 개수 :  22
# 검색어 :  편의점 개수 :  2
# 검색어 :  편의점 개수 :  0
# 검색어 :  편의점 개수 :  11
# ==========[ 어린이집 ] ==========
# 검색어 :  어린이집 개수 :  1
# 검색어 :  어린이집 개수 :  0
# 검색어 :  어린이집 개수 :  0
# 검색어 :  어린이집 개수 :  0
# 검색어 :  어린이집 개수 :  18
# 검색어 :  어린이집 개수 :  12
# 검색어 :  어린이집 개수 :  5
# 검색어 :  어린이집 개수 :  0
# 검색어 :  어린이집 개수 :  0
# 검색어 :  어린이집 개수 :  4
# ==========[ 유치원 ] ==========
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  0
# ==========[ 학교 ] ==========
# ...

# %%
#반복문을 만들것이다.
# 대분류 없는 버전
for i in range (0,26):
    query = address_df2.iloc[i,2]
#     code = address_df2.iloc[i,1]
    
    print("==========[",query,"] ==========")
    #위도&경도 순차적으로 넣기
    for i in range (0, 10):
    #     print(point1.loc[i])
    #     print(point2.loc[i])
        url = 'https://dapi.kakao.com/v2/local/search/keyword.json'

        #원하는 검색어을 스타벅스 자리에, 경도는 x에, 위도는 y에, 반경은 10000에, 카테고리는 위의 표를 보고 해당되는 카테고리를 적어주세요
        params = {'query' : query, 'x' : point2.loc[i], 'y' : point1.loc[i], 'radius' : 2000} #카테고리 참고하기

        ## 본인의 카카오 맵 API의 REST API키를 바로 아래 한글로 된 코드를 지우고 입력해주세요
        headers = {"Authorization": "KakaoAK 876a5e05cd1bb1391f63c6435017f680"}

        total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
#         p_name = requests.get(url, params=params, headers=headers).json()['meta']['category_name']
#         distance = requests.get(url, params=params, headers=headers).json()['meta']['distance']

        ##places는 검색이 잘 되었는지 체크하는 용도로 확인해주시면 됩니다. 다시 말씀드리지만 places에는 45개 데이터가 한계입니다...
        ## 페이지 수를 늘려도, 한 페이지 안에서 보여줄 수 있는 한계치를 아무리 높혀도 45개 이상 안 보여 줍니다. 저는 페이지 설정은 보시다시피 하지는 않았습니다. 
#         places = requests.get(url, params=params, headers=headers).json()['documents']

        ## 원하는 개수는 total변수 안에 있습니다.
        #print(name.loc[i], " : ", total)
        print( "검색어 : ",query, "개수 : ",total)
# Out:
# ==========[ 마트 ] ==========
# 검색어 :  마트 개수 :  72
# 검색어 :  마트 개수 :  55
# 검색어 :  마트 개수 :  9
# 검색어 :  마트 개수 :  21
# 검색어 :  마트 개수 :  86
# 검색어 :  마트 개수 :  71
# 검색어 :  마트 개수 :  76
# 검색어 :  마트 개수 :  21
# 검색어 :  마트 개수 :  5
# 검색어 :  마트 개수 :  80
# ==========[ 편의점 ] ==========
# 검색어 :  편의점 개수 :  73
# 검색어 :  편의점 개수 :  69
# 검색어 :  편의점 개수 :  26
# 검색어 :  편의점 개수 :  41
# 검색어 :  편의점 개수 :  99
# 검색어 :  편의점 개수 :  53
# 검색어 :  편의점 개수 :  107
# 검색어 :  편의점 개수 :  41
# 검색어 :  편의점 개수 :  14
# 검색어 :  편의점 개수 :  116
# ==========[ 어린이집 ] ==========
# 검색어 :  어린이집 개수 :  47
# 검색어 :  어린이집 개수 :  28
# 검색어 :  어린이집 개수 :  1
# 검색어 :  어린이집 개수 :  14
# 검색어 :  어린이집 개수 :  62
# 검색어 :  어린이집 개수 :  41
# 검색어 :  어린이집 개수 :  79
# 검색어 :  어린이집 개수 :  14
# 검색어 :  어린이집 개수 :  5
# 검색어 :  어린이집 개수 :  87
# ==========[ 유치원 ] ==========
# 검색어 :  유치원 개수 :  20
# 검색어 :  유치원 개수 :  4
# 검색어 :  유치원 개수 :  0
# 검색어 :  유치원 개수 :  3
# 검색어 :  유치원 개수 :  18
# 검색어 :  유치원 개수 :  10
# 검색어 :  유치원 개수 :  11
# 검색어 :  유치원 개수 :  3
# 검색어 :  유치원 개수 :  1
# 검색어 :  유치원 개수 :  15
# ...

# %%
# import pandas as pd
# import numpy as np
# import requests

# url = 'https://dapi.kakao.com/v2/local/search/keyword.json' #원하는 검색어을 스타벅스 자리에, 경도는 x에, 위도는 y에, 반경은 10000에, 카테고리는 위의 표를 보고 해당되는 카테고리를 적어주세요 
# params = {'query' : '스타벅스', 'x' : 126.94, 'y' : 37.411, 'radius' : 20000, 'category_group_code' : 'CE7'} ## 본인의 카카오 맵 API의 REST API키를 바로 아래 한글로 된 코드를 지우고 입력해주세요 
# headers = {"Authorization": "KakaoAK 본인 키 입력해주세요(아마 rest API 키인 것 같네요"} 
# total = requests.get(url, params=params, headers=headers).json()['meta']['total_count'] ##places는 검색이 잘 되었는지 체크하는 용도로 확인해주시면 됩니다. 다시 말씀드리지만 places에는 45개 데이터가 한계입니다... ## 페이지 수를 늘려도, 한 페이지 안에서 보여줄 수 있는 한계치를 아무리 높혀도 45개 이상 안 보여 줍니다. 저는 페이지 설정은 보시다시피 하지는 않았습니다. 
# places = requests.get(url, params=params, headers=headers).json()['documents'] ## 원하는 개수는 total변수 안에 있습니다.

# total
