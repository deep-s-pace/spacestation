# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from ast import keyword
from re import S
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd
import pymysql
import schedule
import time

# %%
#회사이름 리스트가 담긴 csv를 읽어오자

csv = pd.read_csv('./gcube_contents.csv')
name = csv['name']
location = csv['location']
category = csv['category']

# %%
#빈리스트도 생성해두자.

df = pd.DataFrame(columns=['name', 'location', 'result_name', 'result_inf'])
df
# Out:
# Empty DataFrame
# Columns: [name, location, result_name, result_inf]
# Index: []

# %%
#우선 사람인을 켠다

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])

driver = webdriver.Chrome('C:/Users/sdg/Desktop/chromedriver_win32/chromedriver.exe')
driver.implicitly_wait(10) # seconds
saram='https://www.saramin.co.kr/zf_user/'
driver.get(saram)
time.sleep(3)

driver.find_element_by_xpath('/html/body/header/div[1]/button').click()
driver.implicitly_wait(15)
driver.find_element_by_xpath('/html/body/div[3]/form/div/div[1]/input').send_keys('청우')
driver.implicitly_wait(15)
driver.find_element_by_xpath('/html/body/div[3]/form/div/button[1]').click()
driver.implicitly_wait(15)
 
button_3rd = driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[3]/a').text
print(button_3rd)
# Out:
# <ipython-input-63-3dfdddff314e>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/sdg/Desktop/chromedriver_win32/chromedriver.exe')
# <ipython-input-63-3dfdddff314e>:12: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/header/div[1]/button').click()
# <ipython-input-63-3dfdddff314e>:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[3]/form/div/div[1]/input').send_keys('청우')
# <ipython-input-63-3dfdddff314e>:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[3]/form/div/button[1]').click()
# 기업정보
# <ipython-input-63-3dfdddff314e>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   button_3rd = driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[3]/a').text

# %%
csv
# Out:
#       no        name location category
# 0      1        가나광고      김천시       광고
# 1      2        가람기획      구미시       공연
# 2      3       가미디자인      상주시       광고
# 3      4          가온      경산시       게임
# 4      5        강신기획      영주시       광고
# ..   ...         ...      ...      ...
# 533  534     KSB강산방송      안동시       방송
# 534  535   mjc댄스아카데미      포항시       공연
# 535  536     TotalCG      경산시    애니매이션
# 536  537     UGN경북뉴스      안동시     지식정보
# 537  538  ZENORD프로덕션      경주시       광고
#
# [538 rows x 4 columns]

# %% [markdown]
# ## 본격 반복&조건문이야

# %%
# 현재 탭 닫기
driver.close()

# 맨 처음 탭으로 변경(0번 탭)
driver.switch_to.window(driver.window_handles[0])

# 로딩 기다리기
time.sleep(5)

#538

# %%
for i in range(534,540):
    csv = pd.read_csv('./gcube_contents.csv')
    name = csv['name']
    name = name[i]
    location = csv['location']
    location = location[i]
    category = csv['category']
    category = category[i]
    
    print("===========[ ",i, " ]=============")
    
    #검색창을 클릭하고 기존 검색어를 삭제한 뒤, 다음 키워드를 넣어
    options = webdriver.ChromeOptions()
    options.add_experimental_option("excludeSwitches", ["enable-logging"])
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[1]/button').click()
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').clear()
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').send_keys(name)
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[2]/button').click()
    driver.implicitly_wait(20)
    
    #지역검색창을 누르고 기업별 지역명을 넣은 뒤, 해당되는 지역구를 클릭하고 검색버튼을 클릭해
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').send_keys(location)
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/div[1]/div[1]/div[2]/div/ul/li/div/label').click()
    driver.implicitly_wait(20)
    driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[4]/button').click()
    driver.implicitly_wait(20)
    
    #우선 값이 있나 없나를 파악한다..
    
    if driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]').text == "'{}' 에 대한 검색결과가 없습니다.\n검색어를 다시 확인해주세요.".format(name) :
        x = "{}에 대한 검색결과 없음".format(name)
        print(x)
        
        #df에 값을 넣는다.
        df.loc[i] = [name, location, x, x]
        
        driver.back()

    else :    
        #조건문을 통해 오류가 없게 하자.
        if driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[2]/a').text == "기업정보" :
            driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[2]/a').click()
            time.sleep(5)

            html = driver.page_source

            #BeautifulSoup을 사용해 웹페이지 분석하기
            soup = BeautifulSoup(html, 'html.parser') #beautifulsoup 객체생성

            text = soup.find_all('div', class_='corp_info')#content > div > div.cont_company_view.introduce > div.box_company_view.company_intro
            text = [each_line.get_text().strip().replace("\t","").replace("\n","") for each_line in text]
            text = soup.select('#company_info_list > div.content')

            for comp in text :
                c_name = comp.select_one('#company_info_list > div.content > div:nth-child(1) > h2').text
                c_info = comp.select_one('#company_info_list > div.content > div:nth-child(1) > div.corp_info').text

                c_name = c_name.strip().replace("\t","").replace("\n","")
                c_info = c_info.strip().replace("\t","").replace("\n","")

                print(c_name)
                print(c_info)

            #기업 정보칸 내 최상단 기업을 클릭해
            driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/section[1]/div[2]/div[1]/div/h2/a').click()

            time.sleep(5)
            #print(driver.window_handles)

            #최근 열린 탭으로 전환(새창)
            driver.switch_to.window(driver.window_handles[-1])

            #로딩 기다리기
            time.sleep(5)

            html = driver.page_source

            #BeautifulSoup을 사용해 웹페이지 분석하기
            soup = BeautifulSoup(html, 'html.parser') #beautifulsoup 객체생성

            #가져올 구역 정하기
            text2 = soup.select('#content > div > div.cont_company_view.introduce > div.box_company_view.company_intro')

            #구역 내 원하는 태그 기반 값 추출하기
            for comp in text2 :
                c_staff = comp.find_all('strong')
            #     c_info = comp.find_all('dd')

                c_staff = [each_line.get_text().strip() for each_line in c_staff]

            #     c_info = [each_line.get_text().strip().replace("\t",",").replace("\n",",") for each_line in c_info]

                print(c_staff)
            #     print(c_info)

            # 현재 탭 닫기
            driver.close()

            # 맨 처음 탭으로 변경(0번 탭)
            driver.switch_to.window(driver.window_handles[0])

            # 로딩 기다리기
            time.sleep(5)
            
            #df에 값을 넣는다.
            df.loc[i] = [name, location, c_name, c_info]
        

        elif driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[2]/a').text == "채용정보" :
            driver.find_element_by_xpath('/html/body/div[3]/div/ul[1]/li[3]/a').click()
            time.sleep(5)

            html = driver.page_source

            #BeautifulSoup을 사용해 웹페이지 분석하기
            soup = BeautifulSoup(html, 'html.parser') #beautifulsoup 객체생성

            text = soup.find_all('div', class_='corp_info')#content > div > div.cont_company_view.introduce > div.box_company_view.company_intro
            text = [each_line.get_text().strip().replace("\t","").replace("\n","") for each_line in text]
            text = soup.select('#company_info_list > div.content')

            for comp in text :
                c_name = comp.select_one('#company_info_list > div.content > div:nth-child(1) > h2').text
                c_info = comp.select_one('#company_info_list > div.content > div:nth-child(1) > div.corp_info').text

                c_name = c_name.strip().replace("\t","").replace("\n","")
                c_info = c_info.strip().replace("\t","").replace("\n","")

                print(c_name)
                print(c_info)

            #기업 정보칸 내 최상단 기업을 클릭해
            driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/section[1]/div[2]/div[1]/div/h2/a').click()

            time.sleep(5)
            #print(driver.window_handles)

            #최근 열린 탭으로 전환(새창)
            driver.switch_to.window(driver.window_handles[-1])

            #로딩 기다리기
            time.sleep(5)

            html = driver.page_source

            #BeautifulSoup을 사용해 웹페이지 분석하기
            soup = BeautifulSoup(html, 'html.parser') #beautifulsoup 객체생성

            #가져올 구역 정하기
            text2 = soup.select('#content > div > div.cont_company_view.introduce > div.box_company_view.company_intro')

            #구역 내 원하는 태그 기반 값 추출하기
            for comp in text2 :
                c_staff = comp.find_all('strong')
            #     c_info = comp.find_all('dd')

                c_staff = [each_line.get_text().strip() for each_line in c_staff]

                print(c_staff)

            # 현재 탭 닫기
            driver.close()

            # 맨 처음 탭으로 변경(0번 탭)
            driver.switch_to.window(driver.window_handles[0])

            # 로딩 기다리기
            time.sleep(5)
            
            #df에 값을 넣는다.
            df.loc[i] = [name, location, c_name, c_info]

        else :
            y = "{}에 대한 검색작업 중 예상치 못한 오류가 발생했습니다.".format(name)
            print(y)
            
            #df에 값을 넣는다.
            df.loc[i] = [name, location, y, y]
        
            driver.back()
# Out:
# ===========[  534  ]=============
# <ipython-input-105-dfe1d9e18f7e>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[1]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').clear()
# <ipython-input-105-dfe1d9e18f7e>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').send_keys(name)
# <ipython-input-105-dfe1d9e18f7e>:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[2]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:25: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').send_keys(location)
# <ipython-input-105-dfe1d9e18f7e>:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:31: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/div[1]/div[1]/div[2]/div/ul/li/div/label').click()
# <ipython-input-105-dfe1d9e18f7e>:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[4]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:38: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   if driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]').text == "'{}' 에 대한 검색결과가 없습니다.\n검색어를 다시 확인해주세요.".format(name) :
# mjc댄스아카데미에 대한 검색결과 없음
# ===========[  535  ]=============
# <ipython-input-105-dfe1d9e18f7e>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[1]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').clear()
# <ipython-input-105-dfe1d9e18f7e>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').send_keys(name)
# <ipython-input-105-dfe1d9e18f7e>:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[2]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:25: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').send_keys(location)
# <ipython-input-105-dfe1d9e18f7e>:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:31: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/div[1]/div[1]/div[2]/div/ul/li/div/label').click()
# <ipython-input-105-dfe1d9e18f7e>:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[4]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:38: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   if driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]').text == "'{}' 에 대한 검색결과가 없습니다.\n검색어를 다시 확인해주세요.".format(name) :
# TotalCG에 대한 검색결과 없음
# ===========[  536  ]=============
# <ipython-input-105-dfe1d9e18f7e>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[1]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').clear()
# <ipython-input-105-dfe1d9e18f7e>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').send_keys(name)
# <ipython-input-105-dfe1d9e18f7e>:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[2]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:25: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').send_keys(location)
# <ipython-input-105-dfe1d9e18f7e>:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:31: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/div[1]/div[1]/div[2]/div/ul/li/div/label').click()
# <ipython-input-105-dfe1d9e18f7e>:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[4]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:38: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   if driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]').text == "'{}' 에 대한 검색결과가 없습니다.\n검색어를 다시 확인해주세요.".format(name) :
# UGN경북뉴스에 대한 검색결과 없음
# ===========[  537  ]=============
# <ipython-input-105-dfe1d9e18f7e>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[1]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').clear()
# <ipython-input-105-dfe1d9e18f7e>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[1]/div/div[1]/input').send_keys(name)
# <ipython-input-105-dfe1d9e18f7e>:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/ul/li[2]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:25: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').send_keys(location)
# <ipython-input-105-dfe1d9e18f7e>:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/span/input').click()
# <ipython-input-105-dfe1d9e18f7e>:31: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[2]/div/div[2]/div[1]/div/div[1]/div[1]/div[2]/div/ul/li/div/label').click()
# <ipython-input-105-dfe1d9e18f7e>:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[2]/div/form/fieldset/div/div[4]/button').click()
# <ipython-input-105-dfe1d9e18f7e>:38: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   if driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]').text == "'{}' 에 대한 검색결과가 없습니다.\n검색어를 다시 확인해주세요.".format(name) :
# ZENORD프로덕션에 대한 검색결과 없음
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 538 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-dfe1d9e18f7e> in <module>
#       2     csv = pd.read_csv('./gcube_contents.csv')
#       3     name = csv['name']
# ----> 4     name = name[i]
#       5     location = csv['location']
#       6     location = location[i]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
#     389             raise KeyError(key)
#
# KeyError: 538

# %%
# df.loc[620] = ["비앤비코퍼레이션(주)  ", "정보없음", "인천 남동구 호구포로 139", "중소기업", "정보없음", "3명"]
df
# Out:
#            name location             result_name  \
# 2         가미디자인      상주시                   가미디자인
# 5       거송광고디자인      영천시                 거송광고디자인
# 6         건강한친구      구미시                (주)건강한친구
# 7          경농신문      상주시                 (주)종원산업
# 9          경북기획      구미시                    만복기획
# ..          ...      ...                     ...
# 531     KDV프로덕션      문경시                 KDV프로덕션
# 534   mjc댄스아카데미      포항시   mjc댄스아카데미에 대한 검색결과 없음
# 535     TotalCG      경산시     TotalCG에 대한 검색결과 없음
# 536     UGN경북뉴스      안동시     UGN경북뉴스에 대한 검색결과 없음
# 537  ZENORD프로덕션      경주시  ZENORD프로덕션에 대한 검색결과 없음
#
#                                             result_inf
# 2                     대표자명장태영업종인쇄업기업주소경북 상주시 경상대로 2878
# 5        대표자명박성희업종광고 대행업기업주소경북 영천시 창신1길 22, 103동 1104호
# 6    설립일                            2016년 11월 14일  ...
# 7    설립일                            2008년 04월 22일  ...
# 9    설립일                            2019년 01월 01일  ...
# ..                                                 ...
# 531  대표자명곽한균업종텔레비전, 비디오 및 기타 영상기기 제조업기업주소경북 문경시 흥덕로...
# 534                              mjc댄스아카데미에 대한 검색결과 없음
# 535                                TotalCG에 대한 검색결과 없음
# 536                                UGN경북뉴스에 대한 검색결과 없음
# 537                             ZENORD프로덕션에 대한 검색결과 없음
#
# [496 rows x 4 columns]

# %%
df.to_csv('gcube_result539.csv', header=False, index=False)
